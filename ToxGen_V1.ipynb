# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
import pandas as pd
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from rdkit import Chem
from rdkit import DataStructs
from rdkit.Chem import AllChem

# %% [markdown]
# # ToxGEN vol.1

# %%
train_df = pd.read_csv('LD50_train.csv')
test_df = pd.read_csv('LD50_test.csv')
print(train_df.head(), '\n\n', test_df.head())
# Out:
#    filename                     smiles  label
# 0  100-01-6    Nc1ccc([N+](=O)[O-])cc1  2.265
# 1  100-02-7    O=[N+]([O-])c1ccc(O)cc1  2.838
# 2  100-14-1  O=[N+]([O-])c1ccc(CCl)cc1  1.977
# 3  100-17-4   COc1ccc([N+](=O)[O-])cc1  1.823
# 4  100-20-9   O=C(Cl)c1ccc(C(=O)Cl)cc1  1.910
#
#     filename                    smiles  label
# 0  100-00-5  O=[N+]([O-])c1ccc(Cl)cc1  2.574
# 1  100-06-1        COc1ccc(C(C)=O)cc1  1.941
# 2  100-36-7                CCN(CC)CCN  1.613
# 3  100-45-8              N#CC1CC=CCC1  2.367
# 4  100-52-7               O=Cc1ccccc1  1.912

# %%
all_smiles = pd.concat([train_df['smiles'], test_df['smiles']])
tokenizer = Tokenizer(char_level=True, filters='', lower=False)
tokenizer.fit_on_texts(all_smiles)
train_seq = tokenizer.texts_to_sequences(train_df['smiles'])
test_seq = tokenizer.texts_to_sequences(test_df['smiles'])
max_length = max(max(len(s) for s in train_seq), max(len(s) for s in test_seq))
train_padded = pad_sequences(train_seq, maxlen=max_length, padding='post')
test_padded = pad_sequences(test_seq, maxlen=max_length, padding='post')
vocab_size = len(tokenizer.word_index) + 1
print((train_padded.shape, test_padded.shape, vocab_size, max_length))
# Out:
# ((5931, 284), (1482, 284), 37, 284)

# %%
X_train_tensor = torch.tensor(train_padded, dtype=torch.long)
y_train_tensor = torch.tensor(train_df['label'].values, dtype=torch.float).view(-1, 1)
X_test_tensor = torch.tensor(test_padded, dtype=torch.long)
y_test_tensor = torch.tensor(test_df['label'].values, dtype=torch.float).view(-1, 1)

train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

train_dataset, val_dataset = train_test_split(train_dataset, test_size=0.2, random_state=42)

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

len(train_loader), len(val_loader), len(test_loader)
# Out:
# (75, 19, 24)

# %%
class VAE(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, latent_dim, n_layers, dropout):
        super(VAE, self).__init__()
        self.latent_dim = latent_dim
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.encoder_lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers=n_layers, dropout=dropout, batch_first=True)
        self.hidden_to_mean = nn.Linear(hidden_dim, latent_dim)
        self.hidden_to_logvar = nn.Linear(hidden_dim, latent_dim)
        self.decoder_lstm = nn.LSTM(latent_dim, embedding_dim, num_layers=n_layers, dropout=dropout, batch_first=True)
        self.outputs_to_vocab = nn.Linear(embedding_dim, vocab_size)

    def encode(self, input):
        embedded = self.embedding(input)
        _, (hidden, _) = self.encoder_lstm(embedded)
        mean = self.hidden_to_mean(hidden[-1])
        logvar = self.hidden_to_logvar(hidden[-1])
        return mean, logvar

    def reparameterize(self, mean, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return mean + eps*std

    def decode(self, z):
        z = z.unsqueeze(1).repeat(1, max_length, 1)
        lstm_out, _ = self.decoder_lstm(z)
        out = self.outputs_to_vocab(lstm_out)
        return out

    def forward(self, input):
        mean, logvar = self.encode(input)
        z = self.reparameterize(mean, logvar)
        return self.decode(z), mean, logvar

# %%
def vae_loss(recon_x, x, mean, logvar):
    recon_loss = nn.CrossEntropyLoss()(recon_x.transpose(1, 2), x)
    kl_div = -0.5 * torch.sum(1 + logvar - mean.pow(2) - logvar.exp())
    return recon_loss + kl_div

def train_vae(model, train_loader, val_loader, optimizer, n_epochs=30):
    model.train()
    for epoch in range(n_epochs):
        total_loss = 0
        for batch_idx, (data, _) in enumerate(train_loader):
            data = data.to(device)
            optimizer.zero_grad()
            recon_batch, mean, logvar = model(data)
            loss = vae_loss(recon_batch, data, mean, logvar)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        print(f'Epoch {epoch}, Loss: {total_loss / len(train_loader)}')

# %%
vocab_size = len(tokenizer.word_index) + 1
embedding_dim = 256
hidden_dim = 512
latent_dim = 256
n_layers = 5
dropout = 0.5

model = VAE(vocab_size, embedding_dim, hidden_dim, latent_dim, n_layers, dropout)
optimizer = optim.Adam(model.parameters(), lr=3e-4)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# VAE(
#   (embedding): Embedding(37, 256)
#   (encoder_lstm): LSTM(256, 512, num_layers=5, batch_first=True, dropout=0.5)
#   (hidden_to_mean): Linear(in_features=512, out_features=256, bias=True)
#   (hidden_to_logvar): Linear(in_features=512, out_features=256, bias=True)
#   (decoder_lstm): LSTM(256, 256, num_layers=5, batch_first=True, dropout=0.5)
#   (outputs_to_vocab): Linear(in_features=256, out_features=37, bias=True)
# )

# %%
train_vae(model, train_loader, val_loader, optimizer, n_epochs=25)
# Out:
# Epoch 0, Loss: 1.5374555150667826
# Epoch 1, Loss: 0.5360402091344197
# Epoch 2, Loss: 0.3818338179588318
# Epoch 3, Loss: 0.3580182190736135
# Epoch 4, Loss: 0.35387581706047055
# Epoch 5, Loss: 0.3470436382293701
# Epoch 6, Loss: 0.3452537739276886
# Epoch 7, Loss: 0.34154662807782493
# Epoch 8, Loss: 0.33991122285525005
# Epoch 9, Loss: 0.34123504161834717
# Epoch 10, Loss: 0.3378802450497945
# Epoch 11, Loss: 0.33528814097245535
# Epoch 12, Loss: 0.3351496394475301
# Epoch 13, Loss: 0.3339887628952662
# Epoch 14, Loss: 0.332522040605545
# Epoch 15, Loss: 0.33339529871940615
# Epoch 16, Loss: 0.3329658810297648
# Epoch 17, Loss: 0.3308826744556427
# Epoch 18, Loss: 0.3302076349655787
# Epoch 19, Loss: 0.33132585207621257
# Epoch 20, Loss: 0.3317698959509532
# Epoch 21, Loss: 0.3297600382566452
# Epoch 22, Loss: 0.32985772252082823
# Epoch 23, Loss: 0.331263796488444
# Epoch 24, Loss: 0.33237616896629335

# %%
def sample_with_temperature(logits, temperature):
    batch_size, seq_length, vocab_size = logits.size()
    scaled_logits = logits.view(batch_size * seq_length, vocab_size) / temperature
    probabilities = torch.nn.functional.softmax(scaled_logits, dim=-1)
    sampled_indices = torch.multinomial(probabilities, 1)
    sampled_indices = sampled_indices.view(batch_size, seq_length)
    return sampled_indices

# %%
def validate_and_diversify_smiles(smiles_list):
    valid_smiles = [smiles for smiles in smiles_list if Chem.MolFromSmiles(smiles)]
    unique_smiles = list(set(valid_smiles))  # Remove duplicates
    return unique_smiles

def generate_smiles(model, tokenizer, n_samples=3, max_length=30, temperature=0.8):
    model.eval()
    generated_smiles = []

    with torch.no_grad():
        while len(generated_smiles) < n_samples:
            z = torch.randn(2 * n_samples, model.latent_dim).to('cuda')  # Generate more candidates
            generated_sequences = model.decode(z)

            if temperature != 1:
                sampled_indices = sample_with_temperature(generated_sequences, temperature)
            else:
                _, sampled_indices = torch.max(generated_sequences, dim=2)

            temp_smiles = ["".join([tokenizer.index_word.get(token_id.item(), '?') for token_id in sequence if token_id != 0])
                           for sequence in sampled_indices]
            valid_unique_smiles = validate_and_diversify_smiles(temp_smiles)

            # Extend the list with new valid and unique SMILES
            generated_smiles.extend(s for s in valid_unique_smiles if s not in generated_smiles)
            generated_smiles = list(set(generated_smiles))  # Ensure uniqueness

    return generated_smiles[:n_samples]

# %%
tokenizer = Tokenizer(char_level=True, filters='', lower=False)
tokenizer.fit_on_texts(all_smiles)
x = generate_smiles(model, tokenizer)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# [23:51:05] SMILES Parse Error: extra close parentheses while parsing: CCC1F(c)CN=cCcC)CCcc1OOCC-1)
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CCC1F(c)CN=cCcC)CCcc1OOCC-1)' for input: 'CCC1F(c)CN=cCcC)CCcc1OOCC-1)'
# [23:51:05] SMILES Parse Error: syntax error while parsing: CNC[C=cCN))cC))=)n1c(C=IcN
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CNC[C=cCN))cC))=)n1c(C=IcN' for input: 'CNC[C=cCN))cC))=)n1c(C=IcN'
# [23:51:05] SMILES Parse Error: syntax error while parsing: CC=CncC+ccCc(ccCC2)c))
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CC=CncC+ccCc(ccCC2)c))' for input: 'CC=CncC+ccCc(ccCC2)c))'
# [23:51:05] SMILES Parse Error: syntax error while parsing: CCOCCC(c=/cNCc)CC((Cc1CCCcC2
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CCOCCC(c=/cNCc)CC((Cc1CCCcC2' for input: 'CCOCCC(c=/cNCc)CC((Cc1CCCcC2'
# [23:51:05] SMILES Parse Error: syntax error while parsing: NCCCNCcCcCcCC=)cc2=SNcc1C
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'NCCCNCcCcCcCC=)cc2=SNcc1C' for input: 'NCCCNCcCcCcCC=)cc2=SNcc1C'
# [23:51:05] SMILES Parse Error: syntax error while parsing: CcOCO]cN=1O))ccC)C()(c()cccOC
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CcOCO]cN=1O))ccC)C()(c()cccOC' for input: 'CcOCO]cN=1O))ccC)C()(c()cccOC'
# [23:51:05] SMILES Parse Error: syntax error while parsing: CCCcO((([(=Oc2OcFc(1OCc]c1
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CCCcO((([(=Oc2OcFc(1OCc]c1' for input: 'CCCcO((([(=Oc2OcFc(1OCc]c1'
# [23:51:05] SMILES Parse Error: syntax error while parsing: CCC(((O2c2()cl(cCcC()HOc1N1
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CCC(((O2c2()cl(cCcC()HOc1N1' for input: 'CCC(((O2c2()cl(cCcC()HOc1N1'
# [23:51:05] SMILES Parse Error: syntax error while parsing: CCO1CCc[CCc(CO=()Clc
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CCO1CCc[CCc(CO=()Clc' for input: 'CCO1CCc[CCc(CO=()Clc'
# [23:51:05] SMILES Parse Error: syntax error while parsing: C=C1S(cc1NCC)CC(C)c](CO()C(
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'C=C1S(cc1NCC)CC(C)c](CO()C(' for input: 'C=C1S(cc1NCC)CC(C)c](CO()C('
# [23:51:05] SMILES Parse Error: syntax error while parsing: CCC=c=(-CCc1ccOC))cn(cc)c
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CCC=c=(-CCc1ccOC))cn(cc)c' for input: 'CCC=c=(-CCc1ccOC))cn(cc)c'
# [23:51:05] SMILES Parse Error: syntax error while parsing: NC(((=C(cOCCc)Cc=C1Cc]1cCc1
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'NC(((=C(cOCCc)Cc=C1Cc]1cCc1' for input: 'NC(((=C(cOCCc)Cc=C1Cc]1cCc1'
# [23:51:05] SMILES Parse Error: extra close parentheses while parsing: CCN(C1c=Occ)11ONC(c))1cO1cC
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CCN(C1c=Occ)11ONC(c))1cO1cC' for input: 'CCN(C1c=Occ)11ONC(c))1cO1cC'
# [23:51:05] SMILES Parse Error: syntax error while parsing: CO1OC(=(((O((c11cn)=[==cC
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CO1OC(=(((O((c11cn)=[==cC' for input: 'CO1OC(=(((O((c11cn)=[==cC'
# [23:51:05] SMILES Parse Error: extra open parentheses for input: 'CCcCCCOc(CcC(C11C1ccccC2(CCc'
# [23:51:05] SMILES Parse Error: syntax error while parsing: CC(CCO()C(CC((Cn=CC)(()cC(11
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CC(CCO()C(CC((Cn=CC)(()cC(11' for input: 'CC(CCO()C(CC((Cn=CC)(()cC(11'
# [23:51:05] SMILES Parse Error: extra close parentheses while parsing: CCCcNCNc)c12cCCOcc)11cNlC])C
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CCCcNCNc)c12cCCOcc)11cNlC])C' for input: 'CCCcNCNc)c12cCCOcc)11cNlC])C'
# [23:51:05] SMILES Parse Error: extra open parentheses for input: 'CC(NCcOOc(C2CccOcC1CCC(C))CCC(c=O1'
# [23:51:05] SMILES Parse Error: syntax error while parsing: CC(cCCO=1c(C)cHcO1C))CO)13
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CC(cCCO=1c(C)cHcO1C))CO)13' for input: 'CC(cCCO=1c(C)cHcO1C))CO)13'
# [23:51:05] SMILES Parse Error: syntax error while parsing: CC(())(C(CCcC)(clC((cC)c[)
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CC(())(C(CCcC)(clC((cC)c[)' for input: 'CC(())(C(CCcC)(clC((cC)c[)'
# [23:51:05] SMILES Parse Error: syntax error while parsing: CC([S1(C))]cO=ccc(C1cc]
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CC([S1(C))]cO=ccc(C1cc]' for input: 'CC([S1(C))]cO=ccc(C1cc]'
# [23:51:05] SMILES Parse Error: extra close parentheses while parsing: CCCOCCCc)ccc=)1Cc)c(ccc)C]
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CCCOCCCc)ccc=)1Cc)c(ccc)C]' for input: 'CCCOCCCc)ccc=)1Cc)c(ccc)C]'
# [23:51:05] SMILES Parse Error: syntax error while parsing: CCCCc=c(=c(ccCcC()CCc[()
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CCCCc=c(=c(ccCcC()CCc[()' for input: 'CCCCc=c(=c(ccCcC()CCc[()'
# [23:51:05] SMILES Parse Error: extra open parentheses for input: 'CNnC(C(N=CC2)(Ccc)cc2OCCc'
# [23:51:05] SMILES Parse Error: syntax error while parsing: OCC=CCO==cC/Oc-c1C)1O2
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'OCC=CCO==cC/Oc-c1C)1O2' for input: 'OCC=CCO==cC/Oc-c1C)1O2'
# [23:51:05] SMILES Parse Error: syntax error while parsing: C=(1Cc)CCccCccC)((Cc1cccC
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'C=(1Cc)CCccCccC)((Cc1cccC' for input: 'C=(1Cc)CCccCccC)((Cc1cccC'
# [23:51:05] SMILES Parse Error: syntax error while parsing: CCO(1O=C(cCC)1))C1)(c1cccC
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CCO(1O=C(cCC)1))C1)(c1cccC' for input: 'CCO(1O=C(cCC)1))C1)(c1cccC'
# [23:51:05] SMILES Parse Error: extra close parentheses while parsing: CCC1C=NOC)C(O)S2cScCccCc)cC1)C(
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CCC1C=NOC)C(O)S2cScCccCc)cC1)C(' for input: 'CCC1C=NOC)C(O)S2cScCccCc)cC1)C('
# [23:51:05] SMILES Parse Error: syntax error while parsing: CCcOOc(S=1l(2(ccN(C(cl1C)
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CCcOOc(S=1l(2(ccN(C(cl1C)' for input: 'CCcOOc(S=1l(2(ccN(C(cl1C)'
# [23:51:05] SMILES Parse Error: syntax error while parsing: CO1ccCc(cC1cl(Cc)cCOc21OCc+cC
# [23:51:05] SMILES Parse Error: Failed parsing SMILES 'CO1ccCc(cC1cl(Cc)cCOc21OCc+cC' for input: 'CO1ccCc(cC1cl(Cc)cCOc21OCc+cC'
# [23:51:06] SMILES Parse Error: syntax error while parsing: CCCCi/)ccc)CcCNC2cc)c(2OCC
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CCCCi/)ccc)CcCNC2cc)c(2OCC' for input: 'CCCCi/)ccc)CcCNC2cc)c(2OCC'
# [23:51:06] SMILES Parse Error: syntax error while parsing: CCc1((cCO)cC1c)Ccc)(c-(CcccCOO)
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CCc1((cCO)cC1c)Ccc)(c-(CcccCOO)' for input: 'CCc1((cCO)cC1c)Ccc)(c-(CcccCOO)'
# [23:51:06] SMILES Parse Error: syntax error while parsing: COCC(cNcOO(1ccC1n21C1(Cc2c4(CF
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'COCC(cNcOO(1ccC1n21C1(Cc2c4(CF' for input: 'COCC(cNcOO(1ccC1n21C1(Cc2c4(CF'
# [23:51:06] SMILES Parse Error: syntax error while parsing: CC(CNl1=1C=c(1(Oc(OcS1C()cO
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CC(CNl1=1C=c(1(Oc(OcS1C()cO' for input: 'CC(CNl1=1C=c(1(Oc(OcS1C()cO'
# [23:51:06] SMILES Parse Error: syntax error while parsing: CC1(C(CC)C1ccO(OC1Cccc))-()
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CC1(C(CC)C1ccO(OC1Cccc))-()' for input: 'CC1(C(CC)C1ccO(OC1Cccc))-()'
# [23:51:06] SMILES Parse Error: syntax error while parsing: CC((C(CCcCOOcC1(CcOCccC-=(
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CC((C(CCcCOOcC1(CcOCccC-=(' for input: 'CC((C(CCcCOOcC1(CcOCccC-=('
# [23:51:06] SMILES Parse Error: syntax error while parsing: CC((Cc=1CC())cCN)C((2COC
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CC((Cc=1CC())cCN)C((2COC' for input: 'CC((Cc=1CC())cCN)C((2COC'
# [23:51:06] SMILES Parse Error: syntax error while parsing: C=C(Cc=(CC21c)c()C)cCc((OC)2
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'C=C(Cc=(CC21c)c()C)cCc((OC)2' for input: 'C=C(Cc=(CC21c)c()C)cCc((OC)2'
# [23:51:06] SMILES Parse Error: extra close parentheses while parsing: CCCcCc))=cC[=c1N)c2cccCC
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CCCcCc))=cC[=c1N)c2cccCC' for input: 'CCCcCc))=cC[=c1N)c2cccCC'
# [23:51:06] SMILES Parse Error: syntax error while parsing: COCC(c()NccCCcccc]nOCC)C1
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'COCC(c()NccCCcccc]nOCC)C1' for input: 'COCC(c()NccCCcccc]nOCC)C1'
# [23:51:06] SMILES Parse Error: extra close parentheses while parsing: CCcc)(CcCO(Nc(CC)OC)cn)(l1c=cCO
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CCcc)(CcCO(Nc(CC)OC)cn)(l1c=cCO' for input: 'CCcc)(CcCO(Nc(CC)OC)cn)(l1c=cCO'
# [23:51:06] SMILES Parse Error: syntax error while parsing: FNC#O(C)=cCcOcCccN31cc]
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'FNC#O(C)=cCcOcCccN31cc]' for input: 'FNC#O(C)=cCcOcCccN31cc]'
# [23:51:06] SMILES Parse Error: syntax error while parsing: CC1((=c)CcCcCc(=clNCCO)/CH
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CC1((=c)CcCcCc(=clNCCO)/CH' for input: 'CC1((=c)CcCcCc(=clNCCO)/CH'
# [23:51:06] SMILES Parse Error: syntax error while parsing: CCCC1CC2cCC()Cc2(CCcCCCC=)C1
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CCCC1CC2cCC()Cc2(CCcCCCC=)C1' for input: 'CCCC1CC2cCC()Cc2(CCcCCCC=)C1'
# [23:51:06] SMILES Parse Error: syntax error while parsing: OOCCc=O/)CC21(=c]cCCC=Cc(
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'OOCCc=O/)CC21(=c]cCCC=Cc(' for input: 'OOCCc=O/)CC21(=c]cCCC=Cc('
# [23:51:06] SMILES Parse Error: syntax error while parsing: C/=(C))(Cc1COCcCcC)C1CC)
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'C/=(C))(Cc1COCcCcC)C1CC)' for input: 'C/=(C))(Cc1COCcCcC)C1CC)'
# [23:51:06] SMILES Parse Error: extra close parentheses while parsing: C=1(cCCcO)cCC)O(n(((c(CCCc(1
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'C=1(cCCcO)cCC)O(n(((c(CCCc(1' for input: 'C=1(cCCcO)cCC)O(n(((c(CCCc(1'
# [23:51:06] SMILES Parse Error: syntax error while parsing: O=C(NcCCOC((NC1nc)Cc(1cH))C11
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'O=C(NcCCOC((NC1nc)Cc(1cH))C11' for input: 'O=C(NcCCOC((NC1nc)Cc(1cH))C11'
# [23:51:06] SMILES Parse Error: syntax error while parsing: CCCrc(=)C=c)(CCC((21CccCcc)cC)F
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CCCrc(=)C=c)(CCC((21CccCcc)cC)F' for input: 'CCCrc(=)C=c)(CCC((21CccCcc)cC)F'
# [23:51:06] SMILES Parse Error: syntax error while parsing: C=OCC1()CC1)2cC))CcO2ccc
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'C=OCC1()CC1)2cC))CcO2ccc' for input: 'C=OCC1()CC1)2cC))CcO2ccc'
# [23:51:06] SMILES Parse Error: extra close parentheses while parsing: COOCc)CCC2CccCc=O)l)C)C
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'COOCc)CCC2CccCc=O)l)C)C' for input: 'COOCc)CCC2CccCc=O)l)C)C'
# [23:51:06] SMILES Parse Error: syntax error while parsing: CC(O(=CC(C(OSCcc=(CcCOc))cC
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CC(O(=CC(C(OSCcc=(CcCOc))cC' for input: 'CC(O(=CC(C(OSCcc=(CcCOc))cC'
# [23:51:06] SMILES Parse Error: syntax error while parsing: CCCCCcCc(c=l1)=COCFC)C)cC1Ccc
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CCCCCcCc(c=l1)=COCFC)C)cC1Ccc' for input: 'CCCCCcCc(c=l1)=COCFC)C)cC1Ccc'
# [23:51:06] SMILES Parse Error: syntax error while parsing: CCCC(N(cOCC()=c(C[OC1c1Cc(NC@
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CCCC(N(cOCC()=c(C[OC1c1Cc(NC@' for input: 'CCCC(N(cOCC()=c(C[OC1c1Cc(NC@'
# [23:51:06] SMILES Parse Error: syntax error while parsing: CC[CCNCc=(=OcOCCO))lC()1cc(c)
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CC[CCNCc=(=OcOCCO))lC()1cc(c)' for input: 'CC[CCNCc=(=OcOCCO))lC()1cc(c)'
# [23:51:06] SMILES Parse Error: syntax error while parsing: CCcc]()CO=2CNc)1Ccn)SCcccF
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CCcc]()CO=2CNc)1Ccn)SCcccF' for input: 'CCcc]()CO=2CNc)1Ccn)SCcccF'
# [23:51:06] SMILES Parse Error: syntax error while parsing: OOCC+C)cOCc(cOncONC)(cc2
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'OOCC+C)cOCc(cOncONC)(cc2' for input: 'OOCC+C)cOCc(cOncONC)(cc2'
# [23:51:06] SMILES Parse Error: unclosed ring for input: 'COcCCCcC(Cc2cNccC=ccC)ccc'
# [23:51:06] SMILES Parse Error: extra close parentheses while parsing: CCC=FO(c)(CcCC)cCCCCCCC)c
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CCC=FO(c)(CcCC)cCCCCCCC)c' for input: 'CCC=FO(c)(CcCC)cCCCCCCC)c'
# [23:51:06] SMILES Parse Error: extra close parentheses while parsing: CCCNCOC)CcC1r=2[cCOc)Occ)c
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CCCNCOC)CcC1r=2[cCOc)Occ)c' for input: 'CCCNCOC)CcC1r=2[cCOc)Occ)c'
# [23:51:06] SMILES Parse Error: syntax error while parsing: CCC(F((CC1C2CCCcCcH()clc)1c1cccF)
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CCC(F((CC1C2CCCcCcH()clc)1c1cccF)' for input: 'CCC(F((CC1C2CCCcCcH()clc)1c1cccF)'
# [23:51:06] SMILES Parse Error: extra close parentheses while parsing: CCcC))CC)1=(cCSC2)Cc)c(O
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CCcC))CC)1=(cCSC2)Cc)c(O' for input: 'CCcC))CC)1=(cCSC2)Cc)c(O'
# [23:51:06] SMILES Parse Error: syntax error while parsing: C(/Pc)((CCncC)=Cc(@ClCS(c))
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'C(/Pc)((CCncC)=Cc(@ClCS(c))' for input: 'C(/Pc)((CCncC)=Cc(@ClCS(c))'
# [23:51:06] SMILES Parse Error: syntax error while parsing: C111C1=cC(CcCcCccC1clcC)c13Oc
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'C111C1=cC(CcCcCccC1clcC)c13Oc' for input: 'C111C1=cC(CcCcCccC1clcC)c13Oc'
# [23:51:06] SMILES Parse Error: syntax error while parsing: OOlC=O)2(CcO1CCcc)l(CCO1-C)1c
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'OOlC=O)2(CcO1CCcc)l(CCO1-C)1c' for input: 'OOlC=O)2(CcO1CCcc)l(CCO1-C)1c'
# [23:51:06] SMILES Parse Error: syntax error while parsing: OCCCC=l((CcncC)CCc((cc))c=)c2
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'OCCCC=l((CcncC)CCc((cc))c=)c2' for input: 'OCCCC=l((CcncC)CCc((cc))c=)c2'
# [23:51:06] SMILES Parse Error: syntax error while parsing: C(CCr(cCc(CC(1c1c)(CccccC2ccc
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'C(CCr(cCc(CC(1c1c)(CccccC2ccc' for input: 'C(CCr(cCc(CC(1c1c)(CccccC2ccc'
# [23:51:06] SMILES Parse Error: syntax error while parsing: CCCc@C()CcCc)c1CS((cCC=11c(Cnc
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CCCc@C()CcCc)c1CS((cCC=11c(Cnc' for input: 'CCCc@C()CcCc)c1CS((cCC=11c(Cnc'
# [23:51:06] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# [23:51:06] SMILES Parse Error: extra close parentheses while parsing: CCCCCcC)cccCcCC1((COCcCC2cC
# [23:51:06] SMILES Parse Error: Failed parsing SMILES 'CCCCCcC)cccCcCC1((COCcCC2cC' for input: 'CCCCCcC)cccCcCC1((COCcCC2cC'
# [23:51:07] SMILES Parse Error: syntax error while parsing: CC(1(C(Cc)cCc-1C))2ccC
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CC(1(C(Cc)cCc-1C))2ccC' for input: 'CC(1(C(Cc)cCc-1C))2ccC'
# [23:51:07] SMILES Parse Error: syntax error while parsing: C1OCOCN(CC(1CN)()cCO)c=
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'C1OCOCN(CC(1CN)()cCO)c=' for input: 'C1OCOCN(CC(1CN)()cCO)c='
# [23:51:07] SMILES Parse Error: syntax error while parsing: N=NClN(CcCCc2Ccc(=C)(c](cCc
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'N=NClN(CcCCc2Ccc(=C)(c](cCc' for input: 'N=NClN(CcCCc2Ccc(=C)(c](cCc'
# [23:51:07] SMILES Parse Error: syntax error while parsing: CCCC2())C(lcC)cco(OCCC1c13
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CCCC2())C(lcC)cco(OCCC1c13' for input: 'CCCC2())C(lcC)cco(OCCC1c13'
# [23:51:07] SMILES Parse Error: syntax error while parsing: OCO(n=C]C)cc()c=CC))ScCCcC)C
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'OCO(n=C]C)cc()c=CC))ScCCcC)C' for input: 'OCO(n=C]C)cc()c=CC))ScCCcC)C'
# [23:51:07] SMILES Parse Error: syntax error while parsing: CCCccc2ClOC(((cOCO1cFc()cClc
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CCCccc2ClOC(((cOCO1cFc()cClc' for input: 'CCCccc2ClOC(((cOCO1cFc()cClc'
# [23:51:07] SMILES Parse Error: extra close parentheses while parsing: C1CPO)SC1CcC(C2C)ccC)(C(c1c]C)OC
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'C1CPO)SC1CcC(C2C)ccC)(C(c1c]C)OC' for input: 'C1CPO)SC1CcC(C2C)ccC)(C(c1c]C)OC'
# [23:51:07] SMILES Parse Error: syntax error while parsing: CCC1cc])OccC1cNO)Sc1c2CCO
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CCC1cc])OccC1cNO)Sc1c2CCO' for input: 'CCC1cc])OccC1cNO)Sc1c2CCO'
# [23:51:07] SMILES Parse Error: extra close parentheses while parsing: CCCcC)(SCcCccOCC211C1cC1l(cc=c
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CCCcC)(SCcCccOCC211C1cC1l(cc=c' for input: 'CCCcC)(SCcCccOCC211C1cC1l(cc=c'
# [23:51:07] SMILES Parse Error: extra close parentheses while parsing: CCcCCNC)clC(CcOlccC)cCc1)42C)
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CCcCCNC)clC(CcOlccC)cCc1)42C)' for input: 'CCcCCNC)clC(CcOlccC)cCc1)42C)'
# [23:51:07] SMILES Parse Error: syntax error while parsing: CC((C=ccOc\CCC)OC(c)CCCccccN
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CC((C=ccOc\CCC)OC(c)CCCccccN' for input: 'CC((C=ccOc\CCC)OC(c)CCCccccN'
# [23:51:07] SMILES Parse Error: syntax error while parsing: COC((CC()c(2C)ONc)CccOSlCcC2
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'COC((CC()c(2C)ONc)CccOSlCcC2' for input: 'COC((CC()c(2C)ONc)CccOSlCcC2'
# [23:51:07] SMILES Parse Error: syntax error while parsing: CCN1OcCOcC(ScO((cO-cc(c-CC1
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CCN1OcCOcC(ScO((cO-cc(c-CC1' for input: 'CCN1OcCOcC(ScO((cO-cc(c-CC1'
# [23:51:07] SMILES Parse Error: extra close parentheses while parsing: CCNCF)cC(CCc)c1c(C()cNC2)cC
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CCNCF)cC(CCc)c1c(C()cNC2)cC' for input: 'CCNCF)cC(CCc)c1c(C()cNC2)cC'
# [23:51:07] SMILES Parse Error: syntax error while parsing: O1C(COCO(C1cCnc)cCNnC=cc(@
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'O1C(COCO(C1cCnc)cCNnC=cc(@' for input: 'O1C(COCO(C1cCnc)cCNnC=cc(@'
# [23:51:07] SMILES Parse Error: extra close parentheses while parsing: CC1COO)ccOCC)ccO)ccccC1
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CC1COO)ccOCC)ccO)ccccC1' for input: 'CC1COO)ccOCC)ccO)ccccC1'
# [23:51:07] SMILES Parse Error: syntax error while parsing: CC(CCcOccOCc)CC(=)l)ccc
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CC(CCcOccOCc)CC(=)l)ccc' for input: 'CC(CCcOccOCc)CC(=)l)ccc'
# [23:51:07] SMILES Parse Error: syntax error while parsing: CNCO(()CCC1C=]Cc=CC11Ccc
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CNCO(()CCC1C=]Cc=CC11Ccc' for input: 'CNCO(()CCC1C=]Cc=CC11Ccc'
# [23:51:07] SMILES Parse Error: extra close parentheses while parsing: CC1C)Cc(CC=)cO(CC1CccC
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CC1C)Cc(CC=)cO(CC1CccC' for input: 'CC1C)Cc(CC=)cO(CC1CccC'
# [23:51:07] SMILES Parse Error: syntax error while parsing: CcP(ccC(CcCO((cCCCO1c)Clccc
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CcP(ccC(CcCO((cCCCO1c)Clccc' for input: 'CcP(ccC(CcCO((cCCCO1c)Clccc'
# [23:51:07] SMILES Parse Error: syntax error while parsing: CC=C1=cCSOcccC1Oc1CCOc(+lc
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CC=C1=cCSOcccC1Oc1CCOc(+lc' for input: 'CC=C1=cCSOcccC1Oc1CCOc(+lc'
# [23:51:07] SMILES Parse Error: syntax error while parsing: C=(OOO(=cCccccc)Cc=c2=CcCc
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'C=(OOO(=cCccccc)Cc=c2=CcCc' for input: 'C=(OOO(=cCccccc)Cc=c2=CcCc'
# [23:51:07] SMILES Parse Error: syntax error while parsing: CCCcNcc()CBCc(SOc1c1cccC1]
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CCCcNcc()CBCc(SOc1c1cccC1]' for input: 'CCCcNcc()CBCc(SOc1c1cccC1]'
# [23:51:07] SMILES Parse Error: extra close parentheses while parsing: CC(CCCNCC)c)))c(1)C])CCNOcC
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CC(CCCNCC)c)))c(1)C])CCNOcC' for input: 'CC(CCCNCC)c)))c(1)C])CCNOcC'
# [23:51:07] SMILES Parse Error: syntax error while parsing: C=c1IcC=)CC)lFOcCC))(C(cC
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'C=c1IcC=)CC)lFOcCC))(C(cC' for input: 'C=c1IcC=)CC)lFOcCC))(C(cC'
# [23:51:07] SMILES Parse Error: syntax error while parsing: OC((1c))OOc(2CCCccCc2c)ccC
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'OC((1c))OOc(2CCCccCc2c)ccC' for input: 'OC((1c))OOc(2CCCccCc2c)ccC'
# [23:51:07] SMILES Parse Error: syntax error while parsing: CC=CCcCCCcCCc1cc(c(N()2
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CC=CCcCCCcCCc1cc(c(N()2' for input: 'CC=CCcCCCcCCc1cc(c(N()2'
# [23:51:07] SMILES Parse Error: syntax error while parsing: CCOCCCC((((c(N)(C)n)OcCF)O2Cc
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CCOCCCC((((c(N)(C)n)OcCF)O2Cc' for input: 'CCOCCCC((((c(N)(C)n)OcCF)O2Cc'
# [23:51:07] SMILES Parse Error: syntax error while parsing: COCCCCCCccB1CCc]cc12(C11(c
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'COCCCCCCccB1CCc]cc12(C11(c' for input: 'COCCCCCCccB1CCc]cc12(C11(c'
# [23:51:07] SMILES Parse Error: syntax error while parsing: CCC((COCCCCcc)=CC)C(cclc
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CCC((COCCCCcc)=CC)C(cclc' for input: 'CCC((COCCCCcc)=CC)C(cclc'
# [23:51:07] SMILES Parse Error: syntax error while parsing: OC=c(cC(COCOCcOOCcccC)=Oclcc=)1))3
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'OC=c(cC(COCOCcOOCcccC)=Oclcc=)1))3' for input: 'OC=c(cC(COCOCcOOCcccC)=Oclcc=)1))3'
# [23:51:07] SMILES Parse Error: syntax error while parsing: NCCl(c/)=cCCCCcCc1O)CCOl)c)
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'NCCl(c/)=cCCCCcCc1O)CCOl)c)' for input: 'NCCl(c/)=cCCCCcCc1O)CCOl)c)'
# [23:51:07] SMILES Parse Error: syntax error while parsing: CCN1(1CN+CCCc(1C(Cccc()c=C)
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CCN1(1CN+CCCc(1C(Cccc()c=C)' for input: 'CCN1(1CN+CCCc(1C(Cccc()c=C)'
# [23:51:07] SMILES Parse Error: syntax error while parsing: CCc(OC=)c(1))COC=CC)cC2CcCc(c
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CCc(OC=)c(1))COC=CC)cC2CcCc(c' for input: 'CCc(OC=)c(1))COC=CC)cC2CcCc(c'
# [23:51:07] SMILES Parse Error: syntax error while parsing: CC((c)c(cNNBc-FOcl=c))OC)(11
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CC((c)c(cNNBc-FOcl=c))OC)(11' for input: 'CC((c)c(cNNBc-FOcl=c))OC)(11'
# [23:51:07] SMILES Parse Error: syntax error while parsing: C(cC(OcCCOC)()ccHc(Occcc(O
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'C(cC(OcCCOC)()ccHc(Occcc(O' for input: 'C(cC(OcCCOC)()ccHc(Occcc(O'
# [23:51:07] SMILES Parse Error: syntax error while parsing: CC+(P)((O()(CCc=)Cc)cOO1c)
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CC+(P)((O()(CCc=)Cc)cOO1c)' for input: 'CC+(P)((O()(CCc=)Cc)cOO1c)'
# [23:51:07] SMILES Parse Error: syntax error while parsing: NCC=(CO(1c1)1(C(c=c=c=()
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'NCC=(CO(1c1)1(C(c=c=c=()' for input: 'NCC=(CO(1c1)1(C(c=c=c=()'
# [23:51:07] SMILES Parse Error: extra close parentheses while parsing: CCCC))C=2CCccOcccccS)Coc)
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CCCC))C=2CCccOcccccS)Coc)' for input: 'CCCC))C=2CCccOcccccS)Coc)'
# [23:51:07] SMILES Parse Error: syntax error while parsing: CCC(NC(2)(c)NC)c=CC2(cc))O
# [23:51:07] SMILES Parse Error: Failed parsing SMILES 'CCC(NC(2)(c)NC)c=CC2(cc))O' for input: 'CCC(NC(2)(c)NC)c=CC2(cc))O'
# [23:51:08] SMILES Parse Error: syntax error while parsing: Cc[=cC(C1O)/c=)ccCCc1c=Cc+On(
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'Cc[=cC(C1O)/c=)ccCCc1c=Cc+On(' for input: 'Cc[=cC(C1O)/c=)ccCCc1c=Cc+On('
# [23:51:08] SMILES Parse Error: syntax error while parsing: CCC(CC())cNnC)(O)C)c)nO[)=Oc)
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CCC(CC())cNnC)(O)C)c)nO[)=Oc)' for input: 'CCC(CC())cNnC)(O)C)c)nO[)=Oc)'
# [23:51:08] SMILES Parse Error: syntax error while parsing: CCcC11O=(ccOc)Cc2cOc4C)Scc
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CCcC11O=(ccOc)Cc2cOc4C)Scc' for input: 'CCcC11O=(ccOc)Cc2cOc4C)Scc'
# [23:51:08] SMILES Parse Error: syntax error while parsing: CCC(cc(1C)c(c)1Ccn1l]cC(
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CCC(cc(1C)c(c)1Ccn1l]cC(' for input: 'CCC(cc(1C)c(c)1Ccn1l]cC('
# [23:51:08] SMILES Parse Error: syntax error while parsing: CCCcCCCccc(C1Cc)S/))Oc2)=C
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CCCcCCCccc(C1Cc)S/))Oc2)=C' for input: 'CCCcCCCccc(C1Cc)S/))Oc2)=C'
# [23:51:08] SMILES Parse Error: extra close parentheses while parsing: CCO1c)C)cC)(CCc1=cl(1C(c[
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CCO1c)C)cC)(CCc1=cl(1C(c[' for input: 'CCO1c)C)cC)(CCc1=cl(1C(c['
# [23:51:08] SMILES Parse Error: syntax error while parsing: CC((OC(Oc(cOCc1(Cc1)Cc)CC)c(Oc)
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CC((OC(Oc(cOCc1(Cc1)Cc)CC)c(Oc)' for input: 'CC((OC(Oc(cOCc1(Cc1)Cc)CC)c(Oc)'
# [23:51:08] SMILES Parse Error: syntax error while parsing: CCccCCO=cC1(CCccO)SC()))))=)
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CCccCCO=cC1(CCccO)SC()))))=)' for input: 'CCccCCO=cC1(CCccO)SC()))))=)'
# [23:51:08] SMILES Parse Error: syntax error while parsing: C=CC((((C)CcCC)(lnO1cC(12O
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'C=CC((((C)CcCC)(lnO1cC(12O' for input: 'C=CC((((C)CcCC)(lnO1cC(12O'
# [23:51:08] SMILES Parse Error: syntax error while parsing: OcCC((O=nC)CCc(=CNccCcCcc(C)CO
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'OcCC((O=nC)CCc(=CNccCcCcc(C)CO' for input: 'OcCC((O=nC)CCc(=CNccCcCcc(C)CO'
# [23:51:08] SMILES Parse Error: syntax error while parsing: +CCCCN(C)()2=11(ccO(c(1C(
# [23:51:08] SMILES Parse Error: Failed parsing SMILES '+CCCCN(C)()2=11(ccO(c(1C(' for input: '+CCCCN(C)()2=11(ccO(c(1C('
# [23:51:08] SMILES Parse Error: syntax error while parsing: C==(CCCNCONcc1[(C)c(2)l1cc22(cCC
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'C==(CCCNCONcc1[(C)c(2)l1cc22(cCC' for input: 'C==(CCCNCONcc1[(C)c(2)l1cc22(cCC'
# [23:51:08] SMILES Parse Error: extra open parentheses for input: 'C(c=Oc1C(OOC)cOCcco1c12cN(CCc'
# [23:51:08] SMILES Parse Error: syntax error while parsing: CC=c(Cn1H(cCc)cc=C(((C)cNOH
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CC=c(Cn1H(cCc)cc=C(((C)cNOH' for input: 'CC=c(Cn1H(cCc)cc=C(((C)cNOH'
# [23:51:08] SMILES Parse Error: extra close parentheses while parsing: CCC1c)CC((occCclCc(clcC)1
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CCC1c)CC((occCclCc(clcC)1' for input: 'CCC1c)CC((occCclCc(clcC)1'
# [23:51:08] SMILES Parse Error: syntax error while parsing: CC1C/c=)c)CcCC]OccC)lC(c
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CC1C/c=)c)CcCC]OccC)lC(c' for input: 'CC1C/c=)c)CcCC]OccC)lC(c'
# [23:51:08] SMILES Parse Error: syntax error while parsing: CCc(cCCcccCO1(c1(2c=c()1c1
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CCc(cCCcccCO1(c1(2c=c()1c1' for input: 'CCc(cCCcccCO1(c1(2c=c()1c1'
# [23:51:08] SMILES Parse Error: syntax error while parsing: C1(c((C(ccc=c)2SOc)=11c()Cc4
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'C1(c((C(ccc=c)2SOc)=11c()Cc4' for input: 'C1(c((C(ccc=c)2SOc)=11c()Cc4'
# [23:51:08] SMILES Parse Error: extra close parentheses while parsing: CCCOC(C)CcC)Cc))cSC(cF1OCc)2C2(l
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CCCOC(C)CcC)Cc))cSC(cF1OCc)2C2(l' for input: 'CCCOC(C)CcC)Cc))cSC(cF1OCc)2C2(l'
# [23:51:08] SMILES Parse Error: syntax error while parsing: CO1==(c)C)=Cc()C))NccCC)OC
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CO1==(c)C)=Cc()C))NccCC)OC' for input: 'CO1==(c)C)=Cc()C))NccCC)OC'
# [23:51:08] SMILES Parse Error: syntax error while parsing: CC=)=((Cn(CcCCcCcOc(OC(2cC](c
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CC=)=((Cn(CcCCcCcOc(OC(2cC](c' for input: 'CC=)=((Cn(CcCCcCcOc(OC(2cC](c'
# [23:51:08] SMILES Parse Error: extra close parentheses while parsing: CC=CO)cccCC1CCcC4c(O)H(()c
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CC=CO)cccCC1CCcC4c(O)H(()c' for input: 'CC=CO)cccCC1CCcC4c(O)H(()c'
# [23:51:08] SMILES Parse Error: extra close parentheses while parsing: CCCcCCCOc)cOcCcCOOccc((O1O)[
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CCCcCCCOc)cOcCcCOOccc((O1O)[' for input: 'CCCcCCCOc)cOcCcCOOccc((O1O)['
# [23:51:08] SMILES Parse Error: extra close parentheses while parsing: CCC1(N)c)CC)(C=cc=((ccc)C
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CCC1(N)c)CC)(C=cc=((ccc)C' for input: 'CCC1(N)c)CC)(C=cc=((ccc)C'
# [23:51:08] SMILES Parse Error: syntax error while parsing: [CCCCOCC=cO)cC1CcO1OcC1C)(O)
# [23:51:08] SMILES Parse Error: Failed parsing SMILES '[CCCCOCC=cO)cC1CcO1OcC1C)(O)' for input: '[CCCCOCC=cO)cC1CcO1OcC1C)(O)'
# [23:51:08] SMILES Parse Error: syntax error while parsing: CCc((()COCCO((ccc)cCC
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CCc((()COCCO((ccc)cCC' for input: 'CCc((()COCCO((ccc)cCC'
# [23:51:08] SMILES Parse Error: syntax error while parsing: CCC((c(O=OCc1cc)C1OCc=(
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CCC((c(O=OCc1cc)C1OCc=(' for input: 'CCC((c(O=OCc1cc)C1OCc=('
# [23:51:08] SMILES Parse Error: syntax error while parsing: CC1(cC(c1)O(cc)OCOcCFO)C()Fr)
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CC1(cC(c1)O(cc)OCOcCFO)C()Fr)' for input: 'CC1(cC(c1)O(cc)OCOcCFO)C()Fr)'
# [23:51:08] SMILES Parse Error: syntax error while parsing: CCCCPCCCCNCc(CcC()]Cc)c)s
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CCCCPCCCCNCc(CcC()]Cc)c)s' for input: 'CCCCPCCCCNCc(CcC()]Cc)c)s'
# [23:51:08] SMILES Parse Error: extra close parentheses while parsing: CCPcC=CcC)(1CcCC(cccCc)1CCc)cc
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CCPcC=CcC)(1CcCC(cccCc)1CCc)cc' for input: 'CCPcC=CcC)(1CcCC(cccCc)1CCc)cc'
# [23:51:08] SMILES Parse Error: syntax error while parsing: CC==OCCc)CC)ccC)CC))c)OC1
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CC==OCCc)CC)ccC)CC))c)OC1' for input: 'CC==OCCc)CC)ccC)CC))c)OC1'
# [23:51:08] SMILES Parse Error: syntax error while parsing: CcCPSOc=11((C)cl)c1c12)l=c
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CcCPSOc=11((C)cl)c1c12)l=c' for input: 'CcCPSOc=11((C)cl)c1c12)l=c'
# [23:51:08] Explicit valence for atom # 1 O, 3, is greater than permitted
# [23:51:08] SMILES Parse Error: syntax error while parsing: CCC(cCOcC()cOCcC(c(cccC(CC
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CCC(cCOcC()cOCcC(c(cccC(CC' for input: 'CCC(cCOcC()cOCcC(c(cccC(CC'
# [23:51:08] SMILES Parse Error: syntax error while parsing: COC((((CCSC(c)C)(2(cNO)
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'COC((((CCSC(c)C)(2(cNO)' for input: 'COC((((CCSC(c)C)(2(cNO)'
# [23:51:08] SMILES Parse Error: syntax error while parsing: CCCN1(CO)Cc(C(1Cn=OCcCCcC(C1)1
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CCCN1(CO)Cc(C(1Cn=OCcCCcC(C1)1' for input: 'CCCN1(CO)Cc(C(1Cn=OCcCCcC(C1)1'
# [23:51:08] SMILES Parse Error: syntax error while parsing: CCCCSOCC=C(CCCO1=lCc1cCc
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CCCCSOCC=C(CCCO1=lCc1cCc' for input: 'CCCCSOCC=C(CCCO1=lCc1cCc'
# [23:51:08] SMILES Parse Error: syntax error while parsing: C=((c)(/(OccCc2=cc)OC1cCH
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'C=((c)(/(OccCc2=cc)OC1cCH' for input: 'C=((c)(/(OccCc2=cc)OC1cCH'
# [23:51:08] SMILES Parse Error: syntax error while parsing: CcC(((cC2(CCcc((c)(c(=C
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CcC(((cC2(CCcc((c)(c(=C' for input: 'CcC(((cC2(CCcc((c)(c(=C'
# [23:51:08] SMILES Parse Error: syntax error while parsing: CCC=(c1/CNCCc1C1cCl]CCcCcCC
# [23:51:08] SMILES Parse Error: Failed parsing SMILES 'CCC=(c1/CNCCc1C1cCl]CCcCcCC' for input: 'CCC=(c1/CNCCc1C1cCl]CCcCcCC'
# [23:51:09] SMILES Parse Error: syntax error while parsing: C=CN()C(cccl(CC[COcCO))c(C2
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'C=CN()C(cccl(CC[COcCO))c(C2' for input: 'C=CN()C(cccl(CC[COcCO))c(C2'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: cCCPO)cC1cClcC)c1C)cCcC))=((2=N
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'cCCPO)cC1cClcC)c1C)cCcC))=((2=N' for input: 'cCCPO)cC1cClcC)c1C)cCcC))=((2=N'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CC=1N=cO)1OS(Oc(CcccC2CCcOc
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CC=1N=cO)1OS(Oc(CcccC2CCcOc' for input: 'CC=1N=cO)1OS(Oc(CcccC2CCcOc'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CCC=(=n(cC)C)[cc==1cOCCcNOC@C
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCC=(=n(cC)C)[cc==1cOCCcNOC@C' for input: 'CCC=(=n(cC)C)[cc==1cOCCcNOC@C'
# [23:51:09] SMILES Parse Error: syntax error while parsing: C@(cCC(CCN(2]CC(c1Cc)c)
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'C@(cCC(CCN(2]CC(c1Cc)c)' for input: 'C@(cCC(CCN(2]CC(c1Cc)c)'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CCC=cc(CCO(CN(NC(CO)c1)c(
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCC=cc(CCO(CN(NC(CO)c1)c(' for input: 'CCC=cc(CCO(CN(NC(CO)c1)c('
# [23:51:09] SMILES Parse Error: syntax error while parsing: CC(ccCcc2O1CCOOO)Ccc3112cC(
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CC(ccCcc2O1CCOOO)Ccc3112cC(' for input: 'CC(ccCcc2O1CCOOO)Ccc3112cC('
# [23:51:09] SMILES Parse Error: syntax error while parsing: CCCCc1C1=))C=c1ccCc2Occ
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCCCc1C1=))C=c1ccCc2Occ' for input: 'CCCCc1C1=))C=c1ccCc2Occ'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CCc)CN)C()=)cC1(Ncc[)1)cC)O
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCc)CN)C()=)cC1(Ncc[)1)cC)O' for input: 'CCc)CN)C()=)cC1(Ncc[)1)cC)O'
# [23:51:09] SMILES Parse Error: syntax error while parsing: OcCP(CcC()2cC(=CC)2ccCcCcCOcOcc
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'OcCP(CcC()2cC(=CC)2ccCcCcCOcOcc' for input: 'OcCP(CcC()2cC(=CC)2ccCcCcCOcOcc'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CCcC==(cO(/()CccCcco))n)()
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCcC==(cO(/()CccCcco))n)()' for input: 'CCcC==(cO(/()CccCcco))n)()'
# [23:51:09] SMILES Parse Error: unclosed ring for input: 'CCCO(CC=c)cccCO(c)C(cC)cOCcC23'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CCCCc)(OC1COCc2OC(C1c)CCcOO)
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCCCc)(OC1COCc2OC(C1c)CCcOO)' for input: 'CCCCc)(OC1COCc2OC(C1c)CCcOO)'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: O=C1CcCcCc(cCCCc=c)COCO2)c=Oc)O
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'O=C1CcCcCc(cCCCc=c)COCO2)c=Oc)O' for input: 'O=C1CcCcCc(cCCCc=c)COCO2)c=Oc)O'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CC(CC)CNC=()c(c)N(1)c
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CC(CC)CNC=()c(c)N(1)c' for input: 'CC(CC)CNC=()c(c)N(1)c'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CcC(Cc/C)1OcCc)clCc(cn))1cC)O)N11C(
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CcC(Cc/C)1OcCc)clCc(cn))1cC)O)N11C(' for input: 'CcC(Cc/C)1OcCc)clCc(cn))1cC)O)N11C('
# [23:51:09] SMILES Parse Error: syntax error while parsing: 1CcCc=1OO2C(cCCcOcCcC)c]H(
# [23:51:09] SMILES Parse Error: Failed parsing SMILES '1CcCc=1OO2C(cCCcOcCcC)c]H(' for input: '1CcCc=1OO2C(cCCcOcCcC)c]H('
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: C1c1CC1C)c2)rcccc=CcccCcC
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'C1c1CC1C)c2)rcccc=CcccCcC' for input: 'C1c1CC1C)c2)rcccc=CcccCcC'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CC=CCCCCCCCcOCC2(l)1)(CC)
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CC=CCCCCCCCcOCC2(l)1)(CC)' for input: 'CC=CCCCCCCCcOCC2(l)1)(CC)'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CCSCSNCCC1cCcCOcOclcOCCC)cc))c)
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCSCSNCCC1cCcCOcOclcOCCC)cc))c)' for input: 'CCSCSNCCC1cCcCOcOclcOCCC)cc))c)'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CC1C(C)ccccCCNc1cC2)C)([(2C
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CC1C(C)ccccCCNc1cC2)C)([(2C' for input: 'CC1C(C)ccccCCNc1cC2)C)([(2C'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CCO(CPC(ccC)(cOCcccc4((c()
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCO(CPC(ccC)(cOCcccc4((c()' for input: 'CCO(CPC(ccC)(cOCcccc4((c()'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CCC1()c=O=(CC1cCcscOc)([Oc)C
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCC1()c=O=(CC1cCcscOc)([Oc)C' for input: 'CCC1()c=O=(CC1cCcscOc)([Oc)C'
# [23:51:09] SMILES Parse Error: syntax error while parsing: C(C+)cCCOCcNc(NC1)c)))O=OCC
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'C(C+)cCCOCcNc(NC1)c)))O=OCC' for input: 'C(C+)cCCOCcNc(NC1)c)))O=OCC'
# [23:51:09] SMILES Parse Error: syntax error while parsing: NCOCc(COCOcC(=c)ccc((1NcSc2NCcc
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'NCOCc(COCOcC(=c)ccc((1NcSc2NCcc' for input: 'NCOCc(COCOcC(=c)ccc((1NcSc2NCcc'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CCC[cN=c)=C(c)c)CC(C1)nCF)C
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCC[cN=c)=C(c)c)CC(C1)nCF)C' for input: 'CCC[cN=c)=C(c)c)CC(C1)nCF)C'
# [23:51:09] SMILES Parse Error: syntax error while parsing: =CC(C(=)(CCC)(ONCC(ccO1ClCcc@C
# [23:51:09] SMILES Parse Error: Failed parsing SMILES '=CC(C(=)(CCC)(ONCC(ccO1ClCcc@C' for input: '=CC(C(=)(CCC)(ONCC(ccO1ClCcc@C'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: cC=CSNPCOCC)Cc))O()CC(CcC)Cc
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'cC=CSNPCOCC)Cc))O()CC(CcC)Cc' for input: 'cC=CSNPCOCC)Cc))O()CC(CcC)Cc'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CCCCCCC1C=1Cc)cCcn(lOcc(CCCc
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCCCCCC1C=1Cc)cCcn(lOcc(CCCc' for input: 'CCCCCCC1C=1Cc)cCcn(lOcc(CCCc'
# [23:51:09] SMILES Parse Error: syntax error while parsing: iSC=Cc=C(C2)COCcCCcc212=1]c
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'iSC=Cc=C(C2)COCcCCcc212=1]c' for input: 'iSC=Cc=C(C2)COCcCCcc212=1]c'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CC(cCC(C=OC)O)cC)(O)N)lccc
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CC(cCC(C=OC)O)cC)(O)N)lccc' for input: 'CC(cCC(C=OC)O)cC)(O)N)lccc'
# [23:51:09] SMILES Parse Error: unclosed ring for input: 'CCC1CCCcC(CCC21(=CCC))1C'
# [23:51:09] SMILES Parse Error: extra open parentheses for input: 'CCCCnccOc=C(ccCcc2)C=OC(C'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CCO(ccNCOC(C1Nc2)((cCcCCc
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCO(ccNCOC(C1Nc2)((cCcCCc' for input: 'CCO(ccNCOC(C1Nc2)((cCcCCc'
# [23:51:09] SMILES Parse Error: syntax error while parsing: C=(1c((CCc1()1Cc(OcNCC(CcO
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'C=(1c((CCc1()1Cc(OcNCC(CcO' for input: 'C=(1c((CCc1()1Cc(OcNCC(CcO'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CCCCC()FOCC(lccCcNc)3C)=
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCCCC()FOCC(lccCcNc)3C)=' for input: 'CCCCC()FOCC(lccCcNc)3C)='
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: C=c1(cOc)))O1CCcc(/cc)C)c3(C
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'C=c1(cOc)))O1CCcc(/cc)C)c3(C' for input: 'C=c1(cOc)))O1CCcc(/cc)C)c3(C'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CC(CC/CcCCc)C)C1)CcCcH)(C)
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CC(CC/CcCCc)C)C1)CcCcH)(C)' for input: 'CC(CC/CcCCc)C)C1)CcCcH)(C)'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CC=C(c1COCiCc=cnCC)(c)11OC]C
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CC=C(c1COCiCc=cnCC)(c)11OC]C' for input: 'CC=C(c1COCiCc=cnCC)(c)11OC]C'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CC11((CC)(COCC)N))CBccc(c1C
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CC11((CC)(COCC)N))CBccc(c1C' for input: 'CC11((CC)(COCC)N))CBccc(c1C'
# [23:51:09] SMILES Parse Error: syntax error while parsing: C=cC1(CcC=cCCcN[)ccCO(C(ccC=(
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'C=cC1(CcC=cCCcN[)ccCO(C(ccC=(' for input: 'C=cC1(CcC=cCCcN[)ccCO(C(ccC=('
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CCC)OC1OCccC2)c)ccc)Ccc(C)cccO
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCC)OC1OCccC2)c)ccc)Ccc(C)cccO' for input: 'CCC)OC1OCccC2)c)ccc)Ccc(C)cccO'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CCC(C(Hc1CCcc1=cOCOOC(ccNl)
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCC(C(Hc1CCcc1=cOCOOC(ccNl)' for input: 'CCC(C(Hc1CCcc1=cOCOOC(ccNl)'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CC(CC)))cOCC(cO)CcCc)F)cO
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CC(CC)))cOCC(cO)CcCc)F)cO' for input: 'CC(CC)))cOCC(cO)CcCc)F)cO'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CCNCSOCCOc=C)O]ccNC1ccC)CcCcC
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCNCSOCCOc=C)O]ccNC1ccC)CcCcC' for input: 'CCNCSOCCOc=C)O]ccNC1ccC)CcCcC'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CC1C1CO(cCN=)(cCc=cC(lcOC
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CC1C1CO(cCN=)(cCc=cC(lcOC' for input: 'CC1C1CO(cCN=)(cCc=cC(lcOC'
# [23:51:09] SMILES Parse Error: syntax error while parsing: OCCcSOcCCccS((C(=cc((cc)c(1=F)
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'OCCcSOcCCccS((C(=cc((cc)c(1=F)' for input: 'OCCcSOcCCccS((C(=cc((cc)c(1=F)'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CCN11(cccc1c2)1)lCC=OC(
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCN11(cccc1c2)1)lCC=OC(' for input: 'CCN11(cccc1c2)1)lCC=OC('
# [23:51:09] SMILES Parse Error: syntax error while parsing: CcPC(C=(()O(cc=CCCC()C(C)CCc(
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CcPC(C=(()O(cc=CCCC()C(C)CCc(' for input: 'CcPC(C=(()O(cc=CCCC()C(C)CCc('
# [23:51:09] SMILES Parse Error: syntax error while parsing: OCC(l(cClC(COcC)c(2c2Ncc1O
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'OCC(l(cClC(COcC)c(2c2Ncc1O' for input: 'OCC(l(cClC(COcC)c(2c2Ncc1O'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CC(1CCO)CcO1cl=cC))C)c(C=(3C
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CC(1CCO)CcO1cl=cC))C)c(C=(3C' for input: 'CC(1CCO)CcO1cl=cC))C)c(C=(3C'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CcC(1=CcC((C)cNC(CcccCcc[
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CcC(1=CcC((C)cNC(CcccCcc[' for input: 'CcC(1=CcC((C)cNC(CcccCcc['
# [23:51:09] SMILES Parse Error: syntax error while parsing: CCP(CcCCO)CcccOl1)CccC)cCcCcO
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCP(CcCCO)CcccOl1)CccC)cCcCcO' for input: 'CCP(CcCCO)CcccOl1)CccC)cCcCcO'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CCCCC(ccCCC1Cc]c(C=(cccc
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCCCC(ccCCC1Cc]c(C=(cccc' for input: 'CCCCC(ccCCC1Cc]c(C=(cccc'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CC(C(=CCc(()FcO))(nOCcc))
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CC(C(=CCc(()FcO))(nOCcc))' for input: 'CC(C(=CCc(()FcO))(nOCcc))'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: COc1=N)CcCcc))CCcl[N)]cS)C1
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'COc1=N)CcCcc))CCcl[N)]cS)C1' for input: 'COc1=N)CcCcc))CCcl[N)]cS)C1'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CcC1)=1c))CcSC((NNNc)C=2c
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CcC1)=1c))CcSC((NNNc)C=2c' for input: 'CcC1)=1c))CcSC((NNNc)C=2c'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CNCCc)N=Occ1ccCC)Cl=ccc](c(])C
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CNCCc)N=Occ1ccCC)Cl=ccc](c(])C' for input: 'CNCCc)N=Occ1ccCC)Cl=ccc](c(])C'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CO=CcCc()C=)CH)COcCSC)cCnCCC2(C
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CO=CcCc()C=)CH)COcCSC)cCnCCC2(C' for input: 'CO=CcCc()C=)CH)COcCSC)cCnCCC2(C'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CCC((cNO(O(c=cOc)O(CCc1Cc(]c2
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCC((cNO(O(c=cOc)O(CCc1Cc(]c2' for input: 'CCC((cNO(O(c=cOc)O(CCc1Cc(]c2'
# [23:51:09] SMILES Parse Error: syntax error while parsing: C=C(lCO/ccccO)O(NC)ccc)cc()
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'C=C(lCO/ccccO)O(NC)ccc)cc()' for input: 'C=C(lCO/ccccO)O(NC)ccc)cc()'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CCCCC=c)COcc)CC2@c21(c)(
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCCCC=c)COcc)CC2@c21(c)(' for input: 'CCCCC=c)COcc)CC2@c21(c)('
# [23:51:09] SMILES Parse Error: syntax error while parsing: CCC(Cc(=1cc)cCccOcOc1CCC(C11)N
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCC(Cc(=1cc)cCccOcOc1CCC(C11)N' for input: 'CCC(Cc(=1cc)cCccOcOc1CCC(C11)N'
# [23:51:09] SMILES Parse Error: syntax error while parsing: Cc1c1lC)cNCcCcC1c1C)c)))()(
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'Cc1c1lC)cNCcCcC1c1C)c)))()(' for input: 'Cc1c1lC)cNCcCcC1c1C)c)))()('
# [23:51:09] SMILES Parse Error: syntax error while parsing: CC(=(=()))C2C)O=C2ccCcOC
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CC(=(=()))C2C)O=C2ccCcOC' for input: 'CC(=(=()))C2C)O=C2ccCcOC'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: OCCC=cCCcOCNCOc(c)c)1cC))(-
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'OCCC=cCCcOCNCOc(c)c)1cC))(-' for input: 'OCCC=cCCcOCNCOc(c)c)1cC))(-'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CCc)C(C(1SCc@cO=cc1)]c1O
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCc)C(C(1SCc@cO=cc1)]c1O' for input: 'CCc)C(C(1SCc@cO=cc1)]c1O'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CC(CC=C(Cn=Oc(c()lc)c1(cC((2c
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CC(CC=C(Cn=Oc(c()lc)c1(cC((2c' for input: 'CC(CC=C(Cn=Oc(c()lc)c1(cC((2c'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CCO[1CCc(=C)Cc(CcCcOcnO)c2O2CCC
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCO[1CCc(=C)Cc(CcCcOcnO)c2O2CCC' for input: 'CCO[1CCc(=C)Cc(CcCcOcnO)c2O2CCC'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CCOCCC=OccC)n)1)cCcO))CCCc1C
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCOCCC=OccC)n)1)cCcO))CCCc1C' for input: 'CCOCCC=OccC)n)1)cCcO))CCCc1C'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: OCCcCCCC)ccC)c)(cCCO(CcCcCcO1
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'OCCcCCCC)ccC)c)(cCCO(CcCcCcO1' for input: 'OCCcCCCC)ccC)c)(cCCO(CcCcCcO1'
# [23:51:09] SMILES Parse Error: syntax error while parsing: SO=((OcC1C=)==CCcC=21=(Cc-)c
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'SO=((OcC1C=)==CCcC=21=(Cc-)c' for input: 'SO=((OcC1C=)==CCcC=21=(Cc-)c'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CCc(C]nOcO/cCcCC)cCH)=]+3)C1
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCc(C]nOcO/cCcCC)cCH)=]+3)C1' for input: 'CCc(C]nOcO/cCcCC)cCH)=]+3)C1'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: OCCCC)(c(2((OCN+OC)cc)cC2c)cccC
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'OCCCC)(c(2((OCN+OC)cc)cC2c)cccC' for input: 'OCCCC)(c(2((OCN+OC)cc)cC2c)cccC'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CCNCC)N(CC(=OCOcc)CCN
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCNCC)N(CC(=OCOcc)CCN' for input: 'CCNCC)N(CC(=OCOcc)CCN'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CC11O)CN(O(CCC1ccCCc)ccO1
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CC11O)CN(O(CCC1ccCCc)ccO1' for input: 'CC11O)CN(O(CCC1ccCCc)ccO1'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CC1NccC/NCC(cl(ccC)CC(cc(c]
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CC1NccC/NCC(cl(ccC)CC(cc(c]' for input: 'CC1NccC/NCC(cl(ccC)CC(cc(c]'
# [23:51:09] SMILES Parse Error: syntax error while parsing: CCNNC==Cc)ccO))3=ccC2(cc[
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCNNC==Cc)ccO))3=ccC2(cc[' for input: 'CCNNC==Cc)ccO))3=ccC2(cc['
# [23:51:09] SMILES Parse Error: syntax error while parsing: CN(C2nO(cCCccc(COC])cCccFC
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CN(C2nO(cCCccc(COC])cCccFC' for input: 'CN(C2nO(cCCccc(COC])cCccFC'
# [23:51:09] SMILES Parse Error: extra close parentheses while parsing: CCOCCC)(ONCl=1)C=(C))CCccc
# [23:51:09] SMILES Parse Error: Failed parsing SMILES 'CCOCCC)(ONCl=1)C=(C))CCccc' for input: 'CCOCCC)(ONCl=1)C=(C))CCccc'
# [23:51:10] SMILES Parse Error: syntax error while parsing: CCCO((c=CCCC))cO/r1)2Ccc)OCO(C
# ...
# [23:51:54] SMILES Parse Error: syntax error while parsing: CCC1O()CO2CSC==Cc==)(Oc)=
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CCC1O()CO2CSC==Cc==)(Oc)=' for input: 'CCC1O()CO2CSC==Cc==)(Oc)='
# [23:51:54] SMILES Parse Error: syntax error while parsing: NCCC(cO(=1c1cOCcN)CcOCc)c(O1
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'NCCC(cO(=1c1cOCcN)CcOCc)c(O1' for input: 'NCCC(cO(=1c1cOCcN)CcOCc)c(O1'
# [23:51:54] SMILES Parse Error: extra close parentheses while parsing: CCONOcOCnCC21cCcCc)C(c)Cc=)CC
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CCONOcOCnCC21cCcCc)C(c)Cc=)CC' for input: 'CCONOcOCnCC21cCcCc)C(c)Cc=)CC'
# [23:51:54] SMILES Parse Error: extra close parentheses while parsing: O1cC))O(S)Ocl)(cccc)c)CN)C)cln
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'O1cC))O(S)Ocl)(cccc)c)CN)C)cln' for input: 'O1cC))O(S)Ocl)(cccc)c)CN)C)cln'
# [23:51:54] SMILES Parse Error: syntax error while parsing: CCc(((OCC(N1cCc)C1Ccc))cc(C3
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CCc(((OCC(N1cCc)C1Ccc))cc(C3' for input: 'CCc(((OCC(N1cCc)C1Ccc))cc(C3'
# [23:51:54] SMILES Parse Error: syntax error while parsing: COCC=O2C()CCc)C(c(CP1)cCccC)
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'COCC=O2C()CCc)C(c(CP1)cCccC)' for input: 'COCC=O2C()CCc)C(c(CP1)cCccC)'
# [23:51:54] SMILES Parse Error: syntax error while parsing: CNC=C=OcCCCcc1c1l)c1C(CCcC
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CNC=C=OcCCCcc1c1l)c1C(CCcC' for input: 'CNC=C=OcCCCcc1c1l)c1C(CCcC'
# [23:51:54] SMILES Parse Error: syntax error while parsing: COcCCCCr=OCC(CcCcOOnC))2c
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'COcCCCCr=OCC(CcCcOOnC))2c' for input: 'COcCCCCr=OCC(CcCcOOnC))2c'
# [23:51:54] SMILES Parse Error: extra close parentheses while parsing: ONOCCCCC)c1=cCCC)l1Cc=cCC
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'ONOCCCCC)c1=cCCC)l1Cc=cCC' for input: 'ONOCCCCC)c1=cCCC)l1Cc=cCC'
# [23:51:54] SMILES Parse Error: syntax error while parsing: C=1(())cC=))()c)c))))OCC(c2cc
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'C=1(())cC=))()c)c))))OCC(c2cc' for input: 'C=1(())cC=))()c)c))))OCC(c2cc'
# [23:51:54] SMILES Parse Error: syntax error while parsing: (CCC(nc)CCcC1Oc)cCccOcO))(
# [23:51:54] SMILES Parse Error: Failed parsing SMILES '(CCC(nc)CCcC1Oc)cCccOcO))(' for input: '(CCC(nc)CCcC1Oc)cCccOcO))('
# [23:51:54] SMILES Parse Error: syntax error while parsing: CC=c(C=Cc)c(cc(((1l(cOc
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CC=c(C=Cc)c(cc(((1l(cOc' for input: 'CC=c(C=Cc)c(cc(((1l(cOc'
# [23:51:54] SMILES Parse Error: extra close parentheses while parsing: C=CC1cc)(=C)C()()Cc1)c[
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'C=CC1cc)(=C)C()()Cc1)c[' for input: 'C=CC1cc)(=C)C()()Cc1)c['
# [23:51:54] SMILES Parse Error: extra close parentheses while parsing: C=Cc=CC1(CCc))Cc==c2Oc(CCC)cc
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'C=Cc=CC1(CCc))Cc==c2Oc(CCC)cc' for input: 'C=Cc=CC1(CCc))Cc==c2Oc(CCC)cc'
# [23:51:54] SMILES Parse Error: syntax error while parsing: CO=1(CCC=cCCC)()c1(lc)()
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CO=1(CCC=cCCC)()c1(lc)()' for input: 'CO=1(CCC=cCCC)()c1(lc)()'
# [23:51:54] SMILES Parse Error: syntax error while parsing: CC((cOC)C()2O1cccCCc)CC(Cc@
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CC((cOC)C()2O1cccCCc)CC(Cc@' for input: 'CC((cOC)C()2O1cccCCc)CC(Cc@'
# [23:51:54] SMILES Parse Error: syntax error while parsing: CCPcc==]CcC=CCCCOc(Cl()1)O
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CCPcc==]CcC=CCCCOc(Cl()1)O' for input: 'CCPcc==]CcC=CCCCOc(Cl()1)O'
# [23:51:54] SMILES Parse Error: syntax error while parsing: CCC1COCO((cClOc1c)cC
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CCC1COCO((cClOc1c)cC' for input: 'CCC1COCO((cClOc1c)cC'
# [23:51:54] SMILES Parse Error: syntax error while parsing: Ccc1(2)OCcccC21=)(CcCCcnOccC(
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'Ccc1(2)OCcccC21=)(CcCCcnOccC(' for input: 'Ccc1(2)OCcccC21=)(CcCCcnOccC('
# [23:51:54] SMILES Parse Error: syntax error while parsing: COcC()ON))O1=(COC)cC(Clc1(2
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'COcC()ON))O1=(COC)cC(Clc1(2' for input: 'COcC()ON))O1=(COC)cC(Clc1(2'
# [23:51:54] SMILES Parse Error: extra close parentheses while parsing: CC=C)()c(CCc((\)()c2c2C((C
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CC=C)()c(CCc((\)()c2c2C((C' for input: 'CC=C)()c(CCc((\)()c2c2C((C'
# [23:51:54] SMILES Parse Error: extra close parentheses while parsing: OCNCCO2=COCc(c=Cc)Ccc=cc))
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'OCNCCO2=COCc(c=Cc)Ccc=cc))' for input: 'OCNCCO2=COCc(c=Cc)Ccc=cc))'
# [23:51:54] SMILES Parse Error: syntax error while parsing: CC()==C)Cc)CCcc#)Cc(3c)C))Oc)O(
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CC()==C)Cc)CCcc#)Cc(3c)C))Oc)O(' for input: 'CC()==C)Cc)CCcc#)Cc(3c)C))Oc)O('
# [23:51:54] SMILES Parse Error: syntax error while parsing: CCCc(CCO)C(N)ccc(C)C())c2CcO
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CCCc(CCO)C(N)ccc(C)C())c2CcO' for input: 'CCCc(CCO)C(N)ccc(C)C())c2CcO'
# [23:51:54] SMILES Parse Error: syntax error while parsing: CCCCC(ccC(COCOlc1)C)C=1
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CCCCC(ccC(COCOlc1)C)C=1' for input: 'CCCCC(ccC(COCOlc1)C)C=1'
# [23:51:54] SMILES Parse Error: extra close parentheses while parsing: CNCS)S(cc(BcOccOCcc(O(1O
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CNCS)S(cc(BcOccOCcc(O(1O' for input: 'CNCS)S(cc(BcOccOCcc(O(1O'
# [23:51:54] SMILES Parse Error: syntax error while parsing: CC((CCF)C=cCcc1CClCC)cCccc
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CC((CCF)C=cCcc1CClCC)cCccc' for input: 'CC((CCF)C=cCcc1CClCC)cCccc'
# [23:51:54] SMILES Parse Error: syntax error while parsing: NCC1CCcCC(1C)=c)CC(()C1)ccCCc1))
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'NCC1CCcCC(1C)=c)CC(()C1)ccCCc1))' for input: 'NCC1CCcCC(1C)=c)CC(()C1)ccCCc1))'
# [23:51:54] SMILES Parse Error: extra close parentheses while parsing: CCCc)c(c=c(cCccCCc(c()c[
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CCCc)c(c=c(cCccCCc(c()c[' for input: 'CCCc)c(c=c(cCccCCc(c()c['
# [23:51:54] SMILES Parse Error: extra close parentheses while parsing: CC)OCO()cO)()(cCc(C()C]ccC1)C)
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CC)OCO()cO)()(cCc(C()C]ccC1)C)' for input: 'CC)OCO()cO)()(cCc(C()C]ccC1)C)'
# [23:51:54] SMILES Parse Error: syntax error while parsing: c(CcCC(cC=ccOC=(cccN(ccN))2c
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'c(CcCC(cC=ccOC=(cccN(ccN))2c' for input: 'c(CcCC(cC=ccOC=(cccN(ccN))2c'
# [23:51:54] SMILES Parse Error: extra close parentheses while parsing: CCPCC))CO+1CcccCcCl)))1c2cN)
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CCPCC))CO+1CcccCcCl)))1c2cN)' for input: 'CCPCC))CO+1CcccCcCl)))1c2cN)'
# [23:51:54] SMILES Parse Error: syntax error while parsing: CCCcON((cc1)cN(2C))O(CcCc)=
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CCCcON((cc1)cN(2C))O(CcCc)=' for input: 'CCCcON((cc1)cN(2C))O(CcCc)='
# [23:51:54] SMILES Parse Error: syntax error while parsing: CC((c(C)l)(cc((CCC()ClCc2cC)1C
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CC((c(C)l)(cc((CCC()ClCc2cC)1C' for input: 'CC((c(C)l)(cc((CCC()ClCc2cC)1C'
# [23:51:54] SMILES Parse Error: syntax error while parsing: CCCCncC1=ONCc1C(c2clOC(c)c1c(F
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CCCCncC1=ONCc1C(c2clOC(c)c1c(F' for input: 'CCCCncC1=ONCc1C(c2clOC(c)c1c(F'
# [23:51:54] SMILES Parse Error: syntax error while parsing: CCCC=(cCN)cCCCNc)1C(CccCc)c
# [23:51:54] SMILES Parse Error: Failed parsing SMILES 'CCCC=(cCN)cCCCNc)1C(CccCc)c' for input: 'CCCC=(cCN)cCCCNc)1C(CccCc)c'
# [23:51:55] SMILES Parse Error: extra close parentheses while parsing: C11C)(=CCCC)cCcCC)O(CcNccc)
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'C11C)(=CCCC)cCcCC)O(CcNccc)' for input: 'C11C)(=CCCC)cCcCC)O(CcNccc)'
# [23:51:55] SMILES Parse Error: extra close parentheses while parsing: CCCSNc1cO21CCC)1Cc)C1Cc-)
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CCCSNc1cO21CCC)1Cc)C1Cc-)' for input: 'CCCSNc1cO21CCC)1Cc)C1Cc-)'
# [23:51:55] SMILES Parse Error: syntax error while parsing: CC[CCcO(Occ(cClcCcCcc)cC)
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CC[CCcO(Occ(cClcCcCcc)cC)' for input: 'CC[CCcO(Occ(cClcCcCcc)cC)'
# [23:51:55] SMILES Parse Error: extra close parentheses while parsing: COCcccCCn)cccc()CCNOc)CC)lC
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'COCcccCCn)cccc()CCNOc)CC)lC' for input: 'COCcccCCn)cccc()CCNOc)CC)lC'
# [23:51:55] SMILES Parse Error: syntax error while parsing: CC=C1=cOc(c)CcC=1c2l=C2(c4)2c
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CC=C1=cOc(c)CcC=1c2l=C2(c4)2c' for input: 'CC=C1=cOc(c)CcC=1c2l=C2(c4)2c'
# [23:51:55] SMILES Parse Error: extra close parentheses while parsing: CC=cNC)/HC)CO1)=)C)c)Cc
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CC=cNC)/HC)CO1)=)C)c)Cc' for input: 'CC=cNC)/HC)CO1)=)C)c)Cc'
# [23:51:55] SMILES Parse Error: extra close parentheses while parsing: C=CCcN)CccCCCC(C)c)C1(ccc(1
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'C=CCcN)CccCCCC(C)c)C1(ccc(1' for input: 'C=CCcN)CccCCCC(C)c)C1(ccc(1'
# [23:51:55] SMILES Parse Error: syntax error while parsing: CCN1POc=(C(Cc1Cc1c=CCCCc
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CCN1POc=(C(Cc1Cc1c=CCCCc' for input: 'CCN1POc=(C(Cc1Cc1c=CCCCc'
# [23:51:55] SMILES Parse Error: syntax error while parsing: C(NCC=cc+n)C)CCC2CCCCCCl1
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'C(NCC=cc+n)C)CCC2CCCCCCl1' for input: 'C(NCC=cc+n)C)CCC2CCCCCCl1'
# [23:51:55] SMILES Parse Error: syntax error while parsing: CC(C)c\(OOCC((1c1O)cc)nc11
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CC(C)c\(OOCC((1c1O)cc)nc11' for input: 'CC(C)c\(OOCC((1c1O)cc)nc11'
# [23:51:55] SMILES Parse Error: syntax error while parsing: =cONCPCc1CcCCCCC(S(C(1C)cC1
# [23:51:55] SMILES Parse Error: Failed parsing SMILES '=cONCPCc1CcCCCCC(S(C(1C)cC1' for input: '=cONCPCc1CcCCCCC(S(C(1C)cC1'
# [23:51:55] SMILES Parse Error: syntax error while parsing: C1NcCccCC(O)(=Cn=ccC)Ccl[
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'C1NcCccCC(O)(=Cn=ccC)Ccl[' for input: 'C1NcCccCC(O)(=Cn=ccC)Ccl['
# [23:51:55] SMILES Parse Error: syntax error while parsing: CC[CC(C(CO/CN)CC)1(CCcllCcCcc(
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CC[CC(C(CO/CN)CC)1(CCcllCcCcc(' for input: 'CC[CC(C(CO/CN)CC)1(CCcllCcCcc('
# [23:51:55] SMILES Parse Error: syntax error while parsing: CCSCCcCN(((CCc([Clc)lcc
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CCSCCcCN(((CCc([Clc)lcc' for input: 'CCSCCcCN(((CCc([Clc)lcc'
# [23:51:55] SMILES Parse Error: syntax error while parsing: CCCC(c()OC)C(=()C(1)CC=c]1lc)O
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CCCC(c()OC)C(=()C(1)CC=c]1lc)O' for input: 'CCCC(c()OC)C(=()C(1)CC=c]1lc)O'
# [23:51:55] SMILES Parse Error: extra close parentheses while parsing: CCCCSC)cC)cCCcccc)NCCccC(O
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CCCCSC)cC)cCCcccc)NCCccC(O' for input: 'CCCCSC)cC)cCCcccc)NCCccC(O'
# [23:51:55] SMILES Parse Error: extra close parentheses while parsing: CCC/OccCCCcCN)C/CcccCCc
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CCC/OccCCCcCN)C/CcccCCc' for input: 'CCC/OccCCCcCN)C/CcccCCc'
# [23:51:55] SMILES Parse Error: syntax error while parsing: OCSC(OOC((C(=[cO3cCccCc)C)([
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'OCSC(OOC((C(=[cO3cCccCc)C)([' for input: 'OCSC(OOC((C(=[cO3cCccCc)C)(['
# [23:51:55] SMILES Parse Error: syntax error while parsing: CCCCCccCO]ccC(CcS(()Ccc)cC
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CCCCCccCO]ccC(CcS(()Ccc)cC' for input: 'CCCCCccCO]ccC(CcS(()Ccc)cC'
# [23:51:55] SMILES Parse Error: syntax error while parsing: CCCC(OOCCc(=ccc(cc]CCCl=)CC1
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CCCC(OOCCc(=ccc(cc]CCCl=)CC1' for input: 'CCCC(OOCCc(=ccc(cc]CCCl=)CC1'
# [23:51:55] SMILES Parse Error: extra close parentheses while parsing: CCcccN=OC2)C1)(c=CCccNc(cc(C
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CCcccN=OC2)C1)(c=CCccNc(cc(C' for input: 'CCcccN=OC2)C1)(c=CCccNc(cc(C'
# [23:51:55] SMILES Parse Error: syntax error while parsing: CCC1CC1())(SO=)c)CcC(Cc2
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CCC1CC1())(SO=)c)CcC(Cc2' for input: 'CCC1CC1())(SO=)c)CcC(Cc2'
# [23:51:55] SMILES Parse Error: syntax error while parsing: OC(c=c(OC(lCO)C(cOcCcc()c((C
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'OC(c=c(OC(lCO)C(cOcCcc()c((C' for input: 'OC(c=c(OC(lCO)C(cOcCcc()c((C'
# [23:51:55] SMILES Parse Error: syntax error while parsing: C11=C/cCC=))Nc=ccOlc))1)C)
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'C11=C/cCC=))Nc=ccOlc))1)C)' for input: 'C11=C/cCC=))Nc=ccOlc))1)C)'
# [23:51:55] SMILES Parse Error: syntax error while parsing: OCC=)CC(O(C(CnC)c=)())1c)c1O
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'OCC=)CC(O(C(CnC)c=)())1c)c1O' for input: 'OCC=)CC(O(C(CnC)c=)())1c)c1O'
# [23:51:55] SMILES Parse Error: syntax error while parsing: C=(nOCCOCC(O1cc=1C)c(Occo)c2C
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'C=(nOCCOCC(O1cc=1C)c(Occo)c2C' for input: 'C=(nOCCOCC(O1cc=1C)c(Occo)c2C'
# [23:51:55] SMILES Parse Error: syntax error while parsing: COC=cc1SC(C()))c((cc1)(cCC(-cOc
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'COC=cc1SC(C()))c((cc1)(cCC(-cOc' for input: 'COC=cc1SC(C()))c((cc1)(cCC(-cOc'
# [23:51:55] SMILES Parse Error: extra close parentheses while parsing: CON)=c(ccOCcc1cCc(Nc=ccc1lC(
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CON)=c(ccOCcc1cCc(Nc=ccc1lC(' for input: 'CON)=c(ccOCcc1cCc(Nc=ccc1lC('
# [23:51:55] SMILES Parse Error: syntax error while parsing: CCC(c)C(OCNcO(OCC((Cc)cCc)
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CCC(c)C(OCNcO(OCC((Cc)cCc)' for input: 'CCC(c)C(OCNcO(OCC((Cc)cCc)'
# [23:51:55] SMILES Parse Error: extra close parentheses while parsing: CCCC)C1lCcCCcOcclc=)c2(c))2
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CCCC)C1lCcCCcOcclc=)c2(c))2' for input: 'CCCC)C1lCcCCcOcclc=)c2(c))2'
# [23:51:55] SMILES Parse Error: syntax error while parsing: CCC1()CC1cc=c=2O)ccc))Nc=(
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CCC1()CC1cc=c=2O)ccc))Nc=(' for input: 'CCC1()CC1cc=c=2O)ccc))Nc=('
# [23:51:55] SMILES Parse Error: syntax error while parsing: CCCCcnO((c(1cO()cc1O)2)c1cN2)CC)
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CCCCcnO((c(1cO()cc1O)2)c1cN2)CC)' for input: 'CCCCcnO((c(1cO()cc1O)2)c1cN2)CC)'
# [23:51:55] SMILES Parse Error: syntax error while parsing: CCO/CcC((CcCNH)1CcCcC)cOH
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CCO/CcC((CcCNH)1CcCcC)cOH' for input: 'CCO/CcC((CcCNH)1CcCcC)cOH'
# [23:51:55] SMILES Parse Error: extra close parentheses while parsing: NcCcnC)CSCCCCCcCCccF1cCc
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'NcCcnC)CSCCCCCcCCccF1cCc' for input: 'NcCcnC)CSCCCCCcCCccF1cCc'
# [23:51:55] SMILES Parse Error: syntax error while parsing: C=1c(c(O+Cc1cn1cccCc3)c2
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'C=1c(c(O+Cc1cn1cccCc3)c2' for input: 'C=1c(c(O+Cc1cn1cccCc3)c2'
# [23:51:55] SMILES Parse Error: extra close parentheses while parsing: OOCO1S)c)(CCCNOc2)ClCOcOcO
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'OOCO1S)c)(CCCNOc2)ClCOcOcO' for input: 'OOCO1S)c)(CCCNOc2)ClCOcOcO'
# [23:51:55] SMILES Parse Error: extra open parentheses for input: 'COC(NCcOcCc1(c1cc1nO1c)1cO(C'
# [23:51:55] SMILES Parse Error: syntax error while parsing: CCcO(P()OcO(CcO(NccCC]ccccO
# [23:51:55] SMILES Parse Error: Failed parsing SMILES 'CCcO(P()OcO(CcO(NccCC]ccccO' for input: 'CCcO(P()OcO(CcO(NccCC]ccccO'
# [23:51:55] SMILES Parse Error: syntax error while parsing: =CcCOC)c)cCCOCCOc)cc12c
# [23:51:55] SMILES Parse Error: Failed parsing SMILES '=CcCOC)c)cCCOCCOc)cc12c' for input: '=CcCOC)c)cCCOCCOc)cc12c'

# %%
x
# Out:
# ['CCC(N)C1/CCCCc=CcONcCO1']
